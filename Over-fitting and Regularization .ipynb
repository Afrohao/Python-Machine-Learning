# %%
from AdvancedAnalytics import ReplaceImputeEncode, NeuralNetwork
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np


df = pd.read_excel("CreditHistory_Clean.xlsx")

# Data map
attribute_map = { 
    'age':['I',(19,120)], 
    'amount': ['I',(0,20000)], 
    'checking': ['N',(1,2,3,4)], 
    'coapp': ['N',(1,2,3)], 
    'depends': ['B',(1,2)], 
    'duration': ['I',(1,72)], 
    'employed': ['N',(1,2,3,4,5)], 
    'existcr': ['N',(1,2,3,4)], 
    'foreign': ['B',(1,2)], 
    'good_bad': ['B',('bad','good')], 
    'history': ['N',(0,1,2,3,4)], 
    'housing':['N',(1,2,3)], 
    'installp': ['N',(1,2,3,4)], 
    'job': ['N',(1,2,3,4)], 
    'marital': ['N',(1,2,3,4)], 
    'other': ['N',(1,2,3)], 
    'property': ['N',(1,2,3,4)], 
    'purpose': ['N',('0', '1','2','3','4','5','6', '8','9','X')],
    'resident': ['N',(1,2,3,4)], 
    'savings': ['N',(1,2,3,4,5)], 
    'telephon': ['B',(1,2)] 
    }

# Data preprocessing
rie = ReplaceImputeEncode(data_map=attribute_map, nominal_encoding='one-hot', interval_scale=None, drop=False, display=True)
encoded_df = rie.fit_transform(df)

# Feature and Target
y = encoded_df['good_bad']
X = encoded_df.drop('good_bad',axis=1)
np_y = np.ravel(y)

# Cross-Validation
best_network = 0
best_alpha = 0
best_F1 = 0
network_list = [(3), (11), (5,4), (6,5), (7,6), (8,7)]
alpha_list = [0, 0.1, 0.15, 0.2, 0.25, 0.3]
score_list = ['accuracy', 'recall', 'precision', 'f1']
for nn in network_list:
    print("\nNetwork: ", nn)
    for a in alpha_list:
        print("\nAlpha: ", a)
        fnn = MLPClassifier(hidden_layer_sizes=nn, activation='tanh', alpha=a, tol=1e-32, solver='lbfgs', max_iter=5000, random_state=12345)
        scores = cross_validate(fnn, X, np_y, scoring=score_list, return_train_score=False, cv=10)
        print("{:.<13s}{:>6s}{:>13s}".format("Metric", "Mean", "Std. Dev."))
        for s in score_list:
            var = "test_"+s
            mean = scores[var].mean()
            std = scores[var].std()
            print("{:.<13s}{:>7.4f}{:>10.4f}".format(s, mean, std))
            if s == "f1" and best_F1 < mean:
                best_F1 = mean
                best_network = nn
                best_alpha = a
# Out:
# ********** Data Preprocessing ***********
# Features Dictionary Contains:
# 3 Interval,
# 4 Binary,
# 14 Nominal, and
# 0 Excluded Attribute(s).
#
# Data contains 1000 observations & 21 columns.
#
#
# Attribute Counts
# ............... Missing  Outliers
# age.......         0         0
# amount....         0         0
# checking..         0         0
# coapp.....         0         0
# depends...         0         0
# duration..         0         0
# employed..         0         0
# existcr...         0         0
# foreign...         0         0
# good_bad..         0         0
# history...         0         0
# housing...         0         0
# installp..         0         0
# job.......         0         0
# marital...         0         0
# other.....         0         0
# property..         0         0
# purpose...         0         0
# resident..         0         0
# savings...         0         0
# telephon..         0         0
#
# Network:  3
#
# Alpha:  0
# Metric.......  Mean    Std. Dev.
# accuracy..... 0.7000    0.0000
# recall....... 1.0000    0.0000
# precision.... 0.7000    0.0000
# f1........... 0.8235    0.0000
#
# Alpha:  0.1
# Metric.......  Mean    Std. Dev.
# accuracy..... 0.7320    0.0525
# recall....... 0.8914    0.0865
# precision.... 0.7716    0.0553
# f1........... 0.8228    0.0351
#
# Alpha:  0.15
# Metric.......  Mean    Std. Dev.
# accuracy..... 0.7280    0.0407
# recall....... 0.8371    0.0345
# precision.... 0.7890    0.0366
# f1........... 0.8117    0.0269
#
# Alpha:  0.2
# Metric.......  Mean    Std. Dev.
# accuracy..... 0.7350    0.0490
# recall....... 0.8186    0.0572
# precision.... 0.8070    0.0360
# f1........... 0.8116    0.0374
#
# Alpha:  0.25
# Metric.......  Mean    Std. Dev.
# accuracy..... 0.7300    0.0525
# recall....... 0.8571    0.0700
# precision.... 0.7825    0.0439
# f1........... 0.8159    0.0369
#
# Alpha:  0.3
# Metric.......  Mean    Std. Dev.
# accuracy..... 0.7260    0.0429
# recall....... 0.8486    0.0649
# precision.... 0.7810    0.0321
# f1........... 0.8118    0.0329
#
# Network:  11
#
# Alpha:  0
# Metric.......  Mean    Std. Dev.
# accuracy..... 0.7000    0.0000
# recall....... 1.0000    0.0000
# precision.... 0.7000    0.0000
# f1........... 0.8235    0.0000
#
# Alpha:  0.1
# Metric.......  Mean    Std. Dev.
# accuracy..... 0.7370    0.0326
# recall....... 0.8429    0.0673
# precision.... 0.7991    0.0433
# f1........... 0.8174    0.0224
#
# Alpha:  0.15
# Metric.......  Mean    Std. Dev.
# accuracy..... 0.7210    0.0386
# recall....... 0.8457    0.0739
# precision.... 0.7789    0.0352
# f1........... 0.8084    0.0310
#
# Alpha:  0.2
# Metric.......  Mean    Std. Dev.
# accuracy..... 0.7350    0.0391
# recall....... 0.8900    0.0655
# precision.... 0.7739    0.0493
# f1........... 0.8246    0.0232
#
# Alpha:  0.25
# Metric.......  Mean    Std. Dev.
# accuracy..... 0.7250    0.0401
# recall....... 0.8357    0.0379
# precision.... 0.7863    0.0335
# f1........... 0.8097    0.0278
#
# Alpha:  0.3
# Metric.......  Mean    Std. Dev.
# accuracy..... 0.7420    0.0506
# recall....... 0.8471    0.0664
# precision.... 0.8008    0.0464
# f1........... 0.8211    0.0356
#
# Network:  (5, 4)
#
# Alpha:  0
# Metric.......  Mean    Std. Dev.
# accuracy..... 0.7000    0.0000
# recall....... 1.0000    0.0000
# precision.... 0.7000    0.0000
# f1........... 0.8235    0.0000
#
# Alpha:  0.1
# Metric.......  Mean    Std. Dev.
# accuracy..... 0.7110    0.0370
# recall....... 0.9371    0.0819
# precision.... 0.7338    0.0479
# f1........... 0.8190    0.0247
#
# Alpha:  0.15
# Metric.......  Mean    Std. Dev.
# accuracy..... 0.6980    0.0140
# recall....... 0.9586    0.0844
# precision.... 0.7141    0.0288
# f1........... 0.8151    0.0200
#
# Alpha:  0.2
# Metric.......  Mean    Std. Dev.
# accuracy..... 0.7310    0.0353
# recall....... 0.9043    0.0688
# precision.... 0.7639    0.0472
# f1........... 0.8248    0.0195
#
# Alpha:  0.25
# Metric.......  Mean    Std. Dev.
# accuracy..... 0.7330    0.0490
# recall....... 0.9214    0.0683
# precision.... 0.7616    0.0653
# f1........... 0.8293    0.0243
#
# Alpha:  0.3
# Metric.......  Mean    Std. Dev.
# accuracy..... 0.7360    0.0484
# recall....... 0.9129    0.0771
# precision.... 0.7671    0.0601
# f1........... 0.8291    0.0277
#
# Network:  (6, 5)
#
# Alpha:  0
# Metric.......  Mean    Std. Dev.
# accuracy..... 0.7000    0.0000
# recall....... 1.0000    0.0000
# precision.... 0.7000    0.0000
# f1........... 0.8235    0.0000
#
# Alpha:  0.1
# Metric.......  Mean    Std. Dev.
# accuracy..... 0.7060    0.0372
# recall....... 0.9086    0.0695
# precision.... 0.7400    0.0501
# f1........... 0.8122    0.0212
#
# Alpha:  0.15
# Metric.......  Mean    Std. Dev.
# accuracy..... 0.7170    0.0297
# recall....... 0.9629    0.0576
# precision.... 0.7275    0.0377
# f1........... 0.8265    0.0163
#
# Alpha:  0.2
# Metric.......  Mean    Std. Dev.
# accuracy..... 0.7240    0.0537
# recall....... 0.8914    0.0926
# precision.... 0.7667    0.0671
# f1........... 0.8186    0.0353
#
# Alpha:  0.25
# Metric.......  Mean    Std. Dev.
# accuracy..... 0.7230    0.0332
# recall....... 0.9200    0.0737
# precision.... 0.7528    0.0574
# f1........... 0.8233    0.0129
#
# Alpha:  0.3
# Metric.......  Mean    Std. Dev.
# accuracy..... 0.7290    0.0295
# recall....... 0.9114    0.0696
# precision.... 0.7594    0.0467
# f1........... 0.8248    0.0143
#
# Network:  (7, 6)
#
# Alpha:  0
# Metric.......  Mean    Std. Dev.
# accuracy..... 0.7000    0.0000
# recall....... 1.0000    0.0000
# precision.... 0.7000    0.0000
# f1........... 0.8235    0.0000
#
# Alpha:  0.1
# Metric.......  Mean    Std. Dev.
# accuracy..... 0.7210    0.0291
# recall....... 0.9314    0.0857
# precision.... 0.7484    0.0617
# f1........... 0.8238    0.0089
#
# Alpha:  0.15
# Metric.......  Mean    Std. Dev.
# accuracy..... 0.7370    0.0405
# recall....... 0.8986    0.0686
# precision.... 0.7721    0.0499
# f1........... 0.8270    0.0245
#
# Alpha:  0.2
# Metric.......  Mean    Std. Dev.
# accuracy..... 0.7300    0.0431
# recall....... 0.9243    0.0801
# precision.... 0.7582    0.0626
# f1........... 0.8277    0.0222
#
# Alpha:  0.25
# Metric.......  Mean    Std. Dev.
# accuracy..... 0.7310    0.0537
# recall....... 0.8657    0.0558
# precision.... 0.7790    0.0482
# f1........... 0.8184    0.0357
#
# Alpha:  0.3
# Metric.......  Mean    Std. Dev.
# accuracy..... 0.7330    0.0412
# recall....... 0.9043    0.0729
# precision.... 0.7657    0.0487
# f1........... 0.8257    0.0254
#
# Network:  (8, 7)
#
# Alpha:  0
# Metric.......  Mean    Std. Dev.
# accuracy..... 0.7000    0.0000
# recall....... 1.0000    0.0000
# precision.... 0.7000    0.0000
# f1........... 0.8235    0.0000
#
# Alpha:  0.1
# Metric.......  Mean    Std. Dev.
# accuracy..... 0.7200    0.0283
# recall....... 0.9414    0.0692
# precision.... 0.7394    0.0455
# f1........... 0.8247    0.0136
#
# Alpha:  0.15
# Metric.......  Mean    Std. Dev.
# accuracy..... 0.7610    0.0493
# recall....... 0.8971    0.0599
# precision.... 0.7968    0.0572
# f1........... 0.8408    0.0276
#
# Alpha:  0.2
# Metric.......  Mean    Std. Dev.
# accuracy..... 0.7390    0.0468
# recall....... 0.8757    0.0734
# precision.... 0.7861    0.0573
# f1........... 0.8246    0.0290
#
# Alpha:  0.25
# Metric.......  Mean    Std. Dev.
# accuracy..... 0.7400    0.0482
# recall....... 0.8971    0.0805
# precision.... 0.7775    0.0582
# f1........... 0.8285    0.0299
#
# Alpha:  0.3
# Metric.......  Mean    Std. Dev.
# accuracy..... 0.7390    0.0501
# recall....... 0.8814    0.0700
# precision.... 0.7819    0.0535
# f1........... 0.8255    0.0319

# %%
print("The Best Network with F1=", best_F1)
print(" Perceptrons: ", best_network)
print(" Alpha:", best_alpha)
# Out:
# The Best Network with F1= 0.8407678776981113
#  Perceptrons:  (8, 7)
#  Alpha: 0.15

# %%
# Evaluate the model
X_train, X_validate, y_train, y_validate = train_test_split(X, np_y,test_size = 0.3, random_state=7)
fnn = MLPClassifier(hidden_layer_sizes=best_network, activation='tanh', alpha=best_alpha, tol=1e-32, solver='lbfgs', max_iter=5000, random_state=12345)
fnn = fnn.fit(X_train,y_train)
NeuralNetwork.display_binary_split_metrics(fnn, X_train, y_train, X_validate, y_validate)
# Out:
# Model Metrics..........       Training     Validation
# Observations...........            700            300
# Features...............             68             68
# Number of Layers.......              2              2
# Number of Outputs......              1              1
# Number of Neurons......             15             15
# Number of Weights......            623            623
# Number of Iterations...             65             65
# Activation Function....       logistic       logistic
# Mean Absolute Error....         0.4279         0.4153
# Avg Squared Error......         0.2139         0.2013
# Accuracy...............         0.6900         0.7233
# Precision..............         0.6900         0.7233
# Recall (Sensitivity)...         1.0000         1.0000
# F1-score...............         0.8166         0.8395
# MISC (Misclassification)...      31.0%          27.7%
#      class 0...............     100.0%         100.0%
#      class 1...............       0.0%           0.0%
#
#
# Training
# Confusion Matrix  Class 0   Class 1
# Class 0.....         0       217
# Class 1.....         0       483
#
#
# Validation
# Confusion Matrix  Class 0   Class 1
# Class 0.....         0        83
# Class 1.....         0       217
